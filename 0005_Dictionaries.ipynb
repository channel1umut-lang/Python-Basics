# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0005_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#key-value pairing

# %%
fitness_dictionary = {"banana":100, "apple":150} # "banana" anahtar oluyor. 100 key oluyor.

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary ["banana"]
# Out:
# 100

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list (fitness_dictionary.values())
# Out:
# [100, 150]

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150}

# %%
fitness_dictionary["banana"] = 200 # banana nin degerini degistirdik.

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"] = 300 # we could add new key and value. However in the lists we were having errore because of the logic of the index.

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
fitness_dictionary.get("appl", 0) #for instance if user enters appl instead of apple it gets 0 value. In that way our application does not stop, it  gives 0 as an output.
# Out:
# 0

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
my_dictionary = {100:"a", 200:"b", 300:"c"} # it is not mandatory to have in the first part "key", it can be "values" also

# %%
my_dictionary[100]
# Out:
# 'a'

# %%
my_dictionary = {"key1":"value1", "key2":"value2", "key3":"value3"} # we can do string string value.

# %%
my_dictionary["key1"]
# Out:
# 'value1'

# %%
my_mixed_dictionary = {"key1":100, "key2":3.14, "key3":[10,20,30]} # we can do also mixed. like int, float and list

# %%
my_mixed_dictionary
# Out:
# {'key1': 100, 'key2': 3.14, 'key3': [10, 20, 30]}

# %%
my_mixed_dictionary["key3"][1] # we took 3. key's second value
# Out:
# 20

# %%
last_dictionary = {"k1":10, "k2":[10,20,30,40,50], "k3":"string", "k4":{"a":100, "b": 200}}

# %%
last_dictionary["k2"][3] #ex
# Out:
# 40

# %%
last_dictionary["k4"]["b"]#ex
# Out:
# 200
