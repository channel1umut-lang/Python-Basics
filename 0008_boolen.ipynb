# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0008_boolen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolen = True

# %%
type(myBoolen)
# Out:
# bool

# %%
myBoolen = False

# %%
5>3
# Out:
# True

# %%
3>5
# Out:
# False

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of google.colab._kernel.Kernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
yas = input("yas= ")  #over mini quiz :)
# Out:
# yas= 25

# %%
int (yas)>18
# Out:
# True
