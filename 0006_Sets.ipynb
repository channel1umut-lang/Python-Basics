# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0006_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# unique elements, unordered

# %%
myList = [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet = set(myList) #lists only unique elements

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,10,20,40,10,20,40}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10) # it did not add

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50) # it added. Because different element

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
mySet.union(mySet2) #wrote ones each elements
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2) #same elements
# Out:
# {30, 40, 50}

# %%
countryList = ["de", "fr", "tr", "fr", "tr", "tr", "de", "nl", "de", "tr"]

# %%
set(countryList)
# Out:
# {'de', 'fr', 'nl', 'tr'}

# %%
len(set(countryList))
# Out:
# 4

# %%
len(countryList)
# Out:
# 10

# %%
emptySet = {}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set() # bos set olusturduk

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)
emptySet.add(20)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}

# %%
emptyList = []

# %%
emptyList = list()

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptyDictionary = dict()

# %%
emptyDictionary ["a"] = 20
emptyDictionary ["b"] = 30

# %%
emptyDictionary
# Out:
# {'a': 20, 'b': 30}
