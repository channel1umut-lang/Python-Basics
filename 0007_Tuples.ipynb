# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0007_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
myList = [10, "a", "b", 3.14]

# %%
type(myList)
# Out:
# list

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %%
#tuple

# %%
myTuple = (10, "a", "b", 3.14)  # normal parantezle yaptik

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
#myTuple[0] = 100

# %%
#immutability

# %%
myTuple
# Out:
# (10, 'a', 'b', 3.14)

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.index(3.14)
# Out:
# 3

# %%
myTuple.count("a")
# Out:
# 1

# %%
resultTuple = (10,100,20)

# %%
resultTuple
# Out:
# (10, 100, 20)

# %%
resultList = list(resultTuple)

# %%
resultList
# Out:
# [10, 100, 20]
