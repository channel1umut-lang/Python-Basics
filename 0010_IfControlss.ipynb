# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0010_IfControlss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y > x
# Out:
# False

# %%
y < x
# Out:
# True

# %%
y = 5

# %%
x >= y
# Out:
# True

# %%
x <= y
# Out:
# True

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.001
# Out:
# False

# %%
x = 10

# %%
y = 8

# %%
x
# Out:
# 10

# %%
y
# Out:
# 8

# %%
x = y

# %%
x
# Out:
# 8

# %%
y
# Out:
# 8

# %%
x = 10

# %%
y
# Out:
# 8

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
2 > 1 or 3 < 2
# Out:
# True

# %%
1 > 2 or 3 < 2
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
5 in [10,20,30]
# Out:
# False

# %%
10 in {10,20,30}
# Out:
# True

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True

# %%
10 in (10,20,30)
# Out:
# True

# %%
my_superhero = "Aquaman"

# %%
my_superhero == "Batman"
# Out:
# False

# %%
my_superhero == "Superman"
# Out:
# False

# %%
if my_superhero == "Batman":
    #indentation
    print("batmannn")
    print("atil samancioglu")
###########---------#########
print("hello python")
# Out:
# hello python

# %%
if 3 > 4:
    print("hello world")
    print("atil")

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero: 5

# %%
if my_superhero == "Superman":
    print("superman")
elif my_superhero == "Batman":
    print("batman")
elif my_superhero == "Aquaman":
    print("aquaman")
elif my_superhero == "Ironman":
    print("ironman")
else:
    print(":(")
# Out:
# :(

# %%
my_age = 100

# %%
if my_age <= 18:
    print("age <= 18")
elif my_age > 18 and my_age <= 30:
    print("18 - age - 30")
elif my_age > 30 and my_age <= 40:
    print("30 - age - 40")
else:
    print("age > 40")
# Out:
# age > 40

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero: 5

# %%
my_superhero_list = ["Spider Man","Iron Man","Thor","Black Widow"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")
# Out:
# :(
