# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0002AS_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"hello"     "umut"
# Out:
# 'helloumut'

# %%
print("hello world")
# Out:
# hello world

# %%
name = "umut yavas"

# %%
type(name)
# Out:
# str

# %%
name.capitalize()
# Out:
# 'Umut yavas'

# %%
name.capitalize #fonksiyon cagirdim
# Out:
# <function str.capitalize()>

# %%
help (name.count) # fonksiyonun ne ise yaradigini bize yardim ediyor.
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
name.count("a") # kac tane a oldugunu gosteriyor
# Out:
# 2

# %%
name.upper() # buyuk yazdi.
# Out:
# 'UMUT YAVAS'

# %%
name
# Out:
# 'umut yavas'

# %%
help (name.encode)
# Out:
# Help on built-in function encode:
#
# encode(encoding='utf-8', errors='strict') method of builtins.str instance
#     Encode the string using the codec registered for encoding.
#
#     encoding
#       The encoding in which to encode the string.
#     errors
#       The error handling scheme to use for encoding errors.
#       The default is 'strict' meaning that encoding errors raise a
#       UnicodeEncodeError.  Other possible values are 'ignore', 'replace' and
#       'xmlcharrefreplace' as well as any other name registered with
#       codecs.register_error that can handle UnicodeEncodeErrors.

# %%
x=5
y=10
x+y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
name
# Out:
# 'umut yavas'

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'UMUT YAVAS'

# %%
len(name) # length. It shows how many characters we have. Space included! len farkli veri tiplerinde farkli anlamlara gelebilir.
# Out:
# 10

# %%
print("umut \nyavas") # \n new line
# Out:
# umut
# yavas

# %%
print("umut \tyavas") # \n arasinda bir tablik bosluk birakiyor.
# Out:
# umut 	yavas
