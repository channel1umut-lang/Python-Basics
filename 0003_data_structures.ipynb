# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0003_data_structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Index Mantigi

# %%
myString = "Umut Yavas"

# %%
myString[3]
# Out:
# 't'

# %%
myString[0]
# Out:
# 'U'

# %%
myString[6]
# Out:
# 'a'

# %%
len(myString)-1
# Out:
# 9

# %%
myName = "james hetfield"

# %%
myName[len(myName)-1] # Son indexi index saymmadan aldigimiz ornek
# Out:
# 'd'

# %%
myName[-1]
# Out:
# 'd'

# %%
myName[-2] # tersten sayiyor.
# Out:
# 'l'

# %% [markdown]
# ###Slicing

# %%
barcode = "ABCDE123123982"

# %%
barcode[0]+barcode[1]+barcode[2]
# Out:
# 'ABC'

# %%
name = "umut"

# %%
surname = "yavas"

# %%
fullname = name + " " + surname

# %%
fullname # fullname * 5 yapiyor ama - veya / 5 yapilmiyor.
# Out:
# 'umut yavas'

# %%
#silicing starting index, stopping index and stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[0:3:] #barcode[starting index : stopping index : stepping size (kacar kacar gidelim)]
# Out:
# 'ABC'

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %% [markdown]
# # Slicing Examples

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode [::3]
# Out:
# 'AD228'

# %%
barcode [3:5:]
# Out:
# 'DE'

# %%
barcode [::-1]
# Out:
# '289321321EDCBA'

# %%
name = "umut yavas"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(...) method of builtins.str instance
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.

# %%
name.index("t")
# Out:
# 3

# %%
name.split()
# Out:
# ['umut', 'yavas']

# %%
type(name.split()) #
# Out:
# list
