# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0001AS_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type(6) #type yazdiktan sonra icine yazdigimiz seyin turunu cikti olarak veriyor.
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
pi = 3.14

# %%
type(pi)
# Out:
# float

# %%
pi + 5
# Out:
# 8.14

# %%
2**5 # uslu sayilar
# Out:
# 32

# %%
10 % 3 # kalani verio
# Out:
# 1

# %%
x=100

# %%
x-5
# Out:
# 95
