# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Python-Basics/blob/main/0004_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LISTS

# %%
myString = "Hello python"

# %%
myString.split()
# Out:
# ['Hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
myList = [10,20,30]

# %%
x=10
y=20
z=30

# %%
myList = [x, y, z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10, 20, 30, 40, 50, 60, 70]

# %%
myList[0]
# Out:
# 10

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100 # burda 1. indexi degistirdik ama stringte bunu yapamiyoruz yani umut`un u sunu degistiremiyorum.

# %%
#mutable yani degistirilebilir ozellik deniyor.

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
len(myList) # kac tane eleman oldugunu veriyor burda onceden kac tane karakter oldugunu gosteriyordu. Yani len`in baska kullaniminida gormus olduk.
# Out:
# 7

# %%
myList[len(myList)-1]
# Out:
# 70

# %% [markdown]
# #LIST FEATURES

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
myList.append(80) # 80 i ekledi listeye

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
len(myList)
# Out:
# 8

# %%
myList.count(20) # kac tane 20 oldugunu bana sayiyor.
# Out:
# 1

# %%
myList.index(40) # 40 in kacinci indexte oldugunu gosteriyor.
# Out:
# 3

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList.insert(2,35) # ikinci indexe 35 sayisini ekledi

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 80]

# %%
myList.pop() # son elemani cikartti
# Out:
# 80

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70]

# %%
myList.remove(40) # listeden 40 i cikartti sadece

# %%
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70]

# %%
myList.reverse() # listeyi tersledi

# %%
myList
# Out:
# [70, 60, 50, 30, 35, 20, 100]

# %%
myList.sort() # kucukten buyuge dogru dizdi, stringi de alfabetik diziyor. mantikli bir dizilim yapiyor.

# %%
myList
# Out:
# [20, 30, 35, 50, 60, 70, 100]

# %%
x = input("enter x") # kullanicidan veri girmesini istedik yazida sayida olur.
# Out:
# enter x10

# %%
x
# Out:
# '10'

# %%
type(x) # x i string aldi gerisini sana birakti.
# Out:
# str

# %%
y = input("enter y")
# Out:
# enter y20

# %%
y
# Out:
# '20'

# %%
z = input("enter z")
# Out:
# enter z30

# %%
z
# Out:
# '30'

# %%
inputList = []

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %% [markdown]
# # Veri Tipi Donusturme

# %%
myInteger = 50

# %%
str(myInteger) # integeri stringe cevirdik
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString) # stringi integera cevirdik
# Out:
# 40

# %%
float(myString) # stringi floatina cevirdik
# Out:
# 40.0

# %%
myString = "python"

# %%
# int(myString) hata verdi cunku mantikli bir donusum degil

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1])*2
# Out:
# 40

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
str(inputList) # birseyi stringe cevirmesi cok kolay ancak tringi baska birseye donustururken mantikli bir donusum olmasi gerek.
# Out:
# "['10', '20', '30']"

# %% [markdown]
# #Ileri seviye listeler

# %%
nameList = ["umut","yavas", "a", "b", "c"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [3.14, 5.2, 4,6, 1,8]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["umut", 100, 3.14] # karisik liste olusturabiliyorum

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10, 20, 30]
list2 = [40, 50, 60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1*2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#list1/2 does not work

# %%
mixedList
# Out:
# ['umut', 100, 3.14]

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[1])
# Out:
# int

# %%
#Nested List

# %%
myNestedList = [10, 20, 3.14, "umut", [1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[-1]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
small = myNestedList[4]

# %%
small
# Out:
# [1, 2, 3]

# %%
type(small)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'umut', [1, 2, 3]]

# %%
myNestedList[4][1]
# Out:
# 2

# %%
firstList = [10,20,30,40,50,60,70,80]

# %%
firstList [::]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70, 80]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
